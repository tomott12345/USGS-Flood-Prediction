# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import xgboost

# %matplotlib inline

from numpy import asarray
import numpy as np
from pandas import concat
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor
from matplotlib import pyplot

import requests, json

# %%
# Get the USGS water data as JSON
usgs_water_api = "http://waterservices.usgs.gov/nwis/iv?sites=01388500&period=P7D&format=json"
api_response = requests.get(usgs_water_api)
water_data = api_response.json()

# Extract interesting data from the JSON
site_name = water_data["value"]["timeSeries"][0]["sourceInfo"]["siteName"]
station_id = water_data["value"]["timeSeries"][0]["sourceInfo"]["siteCode"][0]["value"]
agency_code = water_data["value"]["timeSeries"][0]["sourceInfo"]["siteCode"][0]["agencyCode"]

date_time_last = water_data["value"]["timeSeries"][1]["values"][0]["value"][-3]["dateTime"]
date_time_mid = water_data["value"]["timeSeries"][1]["values"][0]["value"][-2]["dateTime"]
date_time_current = water_data["value"]["timeSeries"][1]["values"][0]["value"][-1]["dateTime"]

streamflow_last = water_data["value"]["timeSeries"][0]["values"][0]["value"][-3]["value"]
streamflow_mid = water_data["value"]["timeSeries"][0]["values"][0]["value"][-2]["value"]
streamflow_current = water_data["value"]["timeSeries"][0]["values"][0]["value"][-1]["value"]

gage_height_last = water_data["value"]["timeSeries"][1]["values"][0]["value"][-3]["value"]
gage_height_mid = water_data["value"]["timeSeries"][1]["values"][0]["value"][-2]["value"]
gage_height_current = water_data["value"]["timeSeries"][1]["values"][0]["value"][-1]["value"]

# Print the data
print(f"Site name: {site_name}")

print(f"Current Datetime: {date_time_current}")
print(f"Last Datetime: {date_time_last}")

print(f"Station ID: {station_id}")
print(f"Agency code: {agency_code}")

print(f"Current Streamflow (ft3/s): {streamflow_last}")
print(f"Last Streamflow (ft3/s): {streamflow_current}")

print(f"Current Gage height (ft): {gage_height_last}")
print(f"Last Gage height (ft): {gage_height_current}")
# Out:
# Site name: Pompton River at Pompton Plains NJ
# Current Datetime: 2024-10-21T12:15:00.000-04:00
# Last Datetime: 2024-10-21T11:45:00.000-04:00
# Station ID: 01388500
# Agency code: USGS
# Current Streamflow (ft3/s): 89.4
# Last Streamflow (ft3/s): 88.0
# Current Gage height (ft): 7.86
# Last Gage height (ft): 7.85

# %%
water_data
# Out:
# {'name': 'ns1:timeSeriesResponseType',
#  'declaredType': 'org.cuahsi.waterml.TimeSeriesResponseType',
#  'scope': 'javax.xml.bind.JAXBElement$GlobalScope',
#  'value': {'queryInfo': {'queryURL': 'http://waterservices.usgs.gov/nwis/ivsites=01388500&period=P7D&format=json',
#    'criteria': {'locationParam': '[ALL:01388500]',
#     'variableParam': 'ALL',
#     'parameter': []},
#    'note': [{'value': '[ALL:01388500]', 'title': 'filter:sites'},
#     {'value': '[mode=PERIOD, period=P7D, modifiedSince=null]',
#      'title': 'filter:timeRange'},
#     {'value': 'methodIds=[ALL]', 'title': 'filter:methodId'},
#     {'value': '2024-10-21T16:39:05.644Z', 'title': 'requestDT'},
#     {'value': 'fca237b0-8fca-11ef-8f5c-2cea7f58f5ca', 'title': 'requestId'},
#     {'value': 'Provisional data are subject to revision. Go to http://waterdata.usgs.gov/nwis/help/?provisional for more information.',
#      'title': 'disclaimer'},
#     {'value': 'vaas01', 'title': 'server'}]},
#   'timeSeries': [{'sourceInfo': {'siteName': 'Pompton River at Pompton Plains NJ',
#      'siteCode': [{'value': '01388500',
#        'network': 'NWIS',
#        'agencyCode': 'USGS'}],
#      'timeZoneInfo': {'defaultTimeZone': {'zoneOffset': '-05:00',
#        'zoneAbbreviation': 'EST'},
#       'daylightSavingsTimeZone': {'zoneOffset': '-04:00',
#        'zoneAbbreviation': 'EDT'},
#       'siteUsesDaylightSavingsTime': True},
#      'geoLocation': {'geogLocation': {'srs': 'EPSG:4326',
#        'latitude': 40.9697222,
#        'longitude': -74.2819444},
#       'localSiteXY': []},
#      'note': [],
#      'siteType': [],
#      'siteProperty': [{'value': 'ST', 'name': 'siteTypeCd'},
#       {'value': '02030103', 'name': 'hucCd'},
#       {'value': '34', 'name': 'stateCd'},
#       {'value': '34031', 'name': 'countyCd'}]},
#     'variable': {'variableCode': [{'value': '00060',
#        'network': 'NWIS',
#        'vocabulary': 'NWIS:UnitValues',
#        'variableID': 45807197,
#        'default': True}],
#      'variableName': 'Streamflow, ft&#179;/s',
#      'variableDescription': 'Discharge, cubic feet per second',
#      'valueType': 'Derived Value',
#      'unit': {'unitCode': 'ft3/s'},
#      'options': {'option': [{'name': 'Statistic', 'optionCode': '00000'}]},
#      'note': [],
#      'noDataValue': -999999.0,
#      'variableProperty': [],
#      'oid': '45807197'},
#     'values': [{'value': [{'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T12:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T13:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T13:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T13:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T13:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T14:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T14:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T14:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T14:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T15:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T15:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T15:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T15:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T16:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T16:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T16:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T16:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T17:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T17:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T17:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T17:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T18:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T18:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T18:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T18:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T19:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T19:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T19:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T19:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T20:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T20:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T20:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T20:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T21:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T21:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T21:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T21:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T22:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T22:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T22:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T22:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T23:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T23:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T23:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-14T23:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T00:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T00:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T00:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T00:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T01:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T01:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T01:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T01:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T02:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T02:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T02:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T02:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T03:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T03:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T03:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T03:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T04:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T04:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T04:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T04:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T05:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T05:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T05:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T05:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T06:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T06:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T06:30:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T06:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T07:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T07:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T07:30:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T07:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T08:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T08:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T08:30:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T08:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T09:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T09:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T09:30:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T09:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T10:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T10:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T10:30:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T10:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T11:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T11:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T11:30:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T11:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T12:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T12:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T12:30:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T12:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T13:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T13:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T13:30:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T13:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T14:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T14:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T14:30:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T14:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T15:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T15:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T15:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T15:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T16:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T16:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T16:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T16:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T17:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T17:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T17:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T17:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T18:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T18:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T18:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T18:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T19:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T19:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T19:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T19:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T20:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T20:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T20:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T20:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T21:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T21:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T21:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T21:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T22:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T22:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T22:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T22:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T23:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T23:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T23:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-15T23:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T00:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T00:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T00:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T00:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T01:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T01:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T01:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T01:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T02:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T02:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T02:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T02:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T03:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T03:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T03:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T03:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T04:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T04:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T04:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T04:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T05:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T05:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T05:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T05:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T06:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T06:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T06:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T06:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T07:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T07:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T07:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T07:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T08:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T08:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T08:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T08:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T09:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T09:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T09:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T09:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T10:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T10:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T10:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T10:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T11:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T11:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T11:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T11:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T12:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T12:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T12:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T12:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T13:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T13:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T13:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T13:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T14:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T14:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T14:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T14:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T15:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T15:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T15:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T15:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T16:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T16:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T16:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T16:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T17:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T17:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T17:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T17:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T18:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T18:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T18:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T18:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T19:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T19:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T19:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T19:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T20:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T20:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T20:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T20:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T21:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T21:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T21:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T21:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T22:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T22:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T22:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T22:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T23:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T23:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T23:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-16T23:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T00:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T00:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T00:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T00:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T01:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T01:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T01:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T01:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T02:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T02:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T02:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T02:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T03:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T03:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T03:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T03:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T04:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T04:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T04:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T04:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T05:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T05:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T05:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T05:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T06:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T06:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T06:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T06:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T07:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T07:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T07:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T07:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T08:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T08:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T08:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T08:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T09:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T09:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T09:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T09:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T10:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T10:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T10:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T10:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T11:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T11:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T11:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T11:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T12:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T12:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T12:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T12:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T13:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T13:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T13:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T13:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T14:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T14:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T14:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T14:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T15:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T15:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T15:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T15:45:00.000-04:00'},
#        {'value': '90.8',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T16:00:00.000-04:00'},
#        {'value': '90.8',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T16:15:00.000-04:00'},
#        {'value': '90.8',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T16:30:00.000-04:00'},
#        {'value': '90.8',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T16:45:00.000-04:00'},
#        {'value': '90.8',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T17:00:00.000-04:00'},
#        {'value': '92.2',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T17:15:00.000-04:00'},
#        {'value': '92.2',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T17:30:00.000-04:00'},
#        {'value': '92.2',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T17:45:00.000-04:00'},
#        {'value': '92.2',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T18:00:00.000-04:00'},
#        {'value': '92.2',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T18:15:00.000-04:00'},
#        {'value': '92.2',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T18:30:00.000-04:00'},
#        {'value': '92.2',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T18:45:00.000-04:00'},
#        {'value': '92.2',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T19:00:00.000-04:00'},
#        {'value': '92.2',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T19:15:00.000-04:00'},
#        {'value': '90.8',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T19:30:00.000-04:00'},
#        {'value': '90.8',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T19:45:00.000-04:00'},
#        {'value': '90.8',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T20:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T20:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T20:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T20:45:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T21:00:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T21:15:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T21:30:00.000-04:00'},
#        {'value': '89.4',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T21:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T22:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T22:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T22:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T22:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T23:00:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T23:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T23:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-17T23:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T00:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T00:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T00:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T00:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T01:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T01:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T01:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T01:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T02:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T02:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T02:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T02:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T03:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T03:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T03:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T03:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T04:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T04:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T04:30:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T04:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T05:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T05:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T05:30:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T05:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T06:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T06:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T06:30:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T06:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T07:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T07:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T07:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T07:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T08:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T08:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T08:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T08:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T09:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T09:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T09:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T09:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T10:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T10:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T10:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T10:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T11:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T11:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T11:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T11:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T12:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T12:15:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T12:30:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T12:45:00.000-04:00'},
#        {'value': '88.0',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T13:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T13:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T13:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T13:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T14:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T14:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T14:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T14:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T15:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T15:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T15:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T15:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T16:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T16:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T16:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T16:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T17:00:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T17:15:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T17:30:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T17:45:00.000-04:00'},
#        {'value': '86.7',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T18:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T18:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T18:30:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T18:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T19:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T19:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T19:30:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T19:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T20:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T20:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T20:30:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T20:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T21:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T21:15:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T21:30:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T21:45:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T22:00:00.000-04:00'},
#        {'value': '85.3',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-18T22:15:00.000-04:00'},
# ...
#         'dateTime': '2024-10-20T00:30:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T00:45:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T01:00:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T01:15:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T01:30:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T01:45:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T02:00:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T02:15:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T02:30:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T02:45:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T03:00:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T03:15:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T03:30:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T03:45:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T04:00:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T04:15:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T04:30:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T04:45:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T05:00:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T05:15:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T05:30:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T05:45:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T06:00:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T06:15:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T06:30:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T06:45:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T07:00:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T07:15:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T07:30:00.000-04:00'},
#        {'value': '7.84',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T07:45:00.000-04:00'},
#        {'value': '7.84',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T08:00:00.000-04:00'},
#        {'value': '7.84',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T08:15:00.000-04:00'},
#        {'value': '7.84',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T08:30:00.000-04:00'},
#        {'value': '7.84',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T08:45:00.000-04:00'},
#        {'value': '7.84',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T09:00:00.000-04:00'},
#        {'value': '7.84',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T09:15:00.000-04:00'},
#        {'value': '7.84',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T09:30:00.000-04:00'},
#        {'value': '7.84',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T09:45:00.000-04:00'},
#        {'value': '7.84',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T10:00:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T10:15:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T10:30:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T10:45:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T11:00:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T11:15:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T11:30:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T11:45:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T12:00:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T12:15:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T12:30:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T12:45:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T13:00:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T13:15:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T13:30:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T13:45:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T14:00:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T14:15:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T14:30:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T14:45:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T15:00:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T15:15:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T15:30:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T15:45:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T16:00:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T16:15:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T16:30:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T16:45:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T17:00:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T17:15:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T17:30:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T17:45:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T18:00:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T18:15:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T18:30:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T18:45:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T19:00:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T19:15:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T19:30:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T19:45:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T20:00:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T20:15:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T20:30:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T20:45:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T21:00:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T21:15:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T21:30:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T21:45:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T22:00:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T22:15:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T22:30:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T22:45:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T23:00:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T23:15:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T23:30:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-20T23:45:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T00:00:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T00:15:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T00:30:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T00:45:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T01:00:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T01:15:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T01:30:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T01:45:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T02:00:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T02:15:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T02:30:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T02:45:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T03:00:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T03:15:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T03:30:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T03:45:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T04:00:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T04:15:00.000-04:00'},
#        {'value': '7.88',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T04:30:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T04:45:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T05:00:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T05:15:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T05:30:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T05:45:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T06:00:00.000-04:00'},
#        {'value': '7.87',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T06:15:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T06:30:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T06:45:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T07:00:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T07:15:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T07:30:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T07:45:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T08:00:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T08:15:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T08:30:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T08:45:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T09:00:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T09:15:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T09:30:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T09:45:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T10:00:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T10:15:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T10:30:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T10:45:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T11:00:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T11:15:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T11:30:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T11:45:00.000-04:00'},
#        {'value': '7.86',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T12:00:00.000-04:00'},
#        {'value': '7.85',
#         'qualifiers': ['P'],
#         'dateTime': '2024-10-21T12:15:00.000-04:00'}],
#       'qualifier': [{'qualifierCode': 'P',
#         'qualifierDescription': 'Provisional data subject to revision.',
#         'qualifierID': 0,
#         'network': 'NWIS',
#         'vocabulary': 'uv_rmk_cd'}],
#       'qualityControlLevel': [],
#       'method': [{'methodDescription': '', 'methodID': 194446}],
#       'source': [],
#       'offset': [],
#       'sample': [],
#       'censorCode': []}],
#     'name': 'USGS:01388500:00065:00000'}]},
#  'nil': False,
#  'globalScope': True,
#  'typeSubstituted': False}

# %%
# Enter the begin and end dates for the gage and flow data
begin_date = '2022-01-01T00:00:00.000-05:00'
end_date = '2024-10-21T12:00:00.000-05:00'

# %%
#Read in raw stream gage data
gage = pd.read_csv('https://nwis.waterservices.usgs.gov/nwis/iv/?sites=01388500&parameterCd=00065&startDT='+begin_date+'&endDT='+end_date+'&siteStatus=all&format=rdb', sep='\t', skiprows=27)
gage = gage.iloc[1: , :]
gage['194446_00065'] = gage['194446_00065'].astype(float)
gage = gage[['datetime','194446_00065']]
gage = gage.set_index('datetime')
gage.head()
# Out:
#                   194446_00065
# datetime
# 2022-01-01 01:00           8.3
# 2022-01-01 01:15           8.3
# 2022-01-01 01:30           8.3
# 2022-01-01 01:45           8.3
# 2022-01-01 02:00           8.3

# %%
#Read in raw flow data
flow = pd.read_csv('https://waterservices.usgs.gov/nwis/iv/?sites=01388500&parameterCd=00060&startDT='+begin_date+'&endDT='+end_date+'&siteStatus=all&format=rdb', sep='\t', skiprows=27)
flow = flow.iloc[1: , :]
flow['194445_00060'] = flow['194445_00060'].astype(float)
flow = flow[['datetime','194445_00060']]
flow = flow.set_index('datetime')
flow.head()
# Out:
#                   194445_00060
# datetime
# 2022-01-01 01:00         248.0
# 2022-01-01 01:15         248.0
# 2022-01-01 01:30         248.0
# 2022-01-01 01:45         248.0
# 2022-01-01 02:00         248.0

# %%
# Merge datasets together on datetime index and check if everything is good
df=pd.merge(gage, flow, how='inner', left_index=True, right_index=True)
df.head()
# Out:
#                   194446_00065  194445_00060
# datetime
# 2022-01-01 01:00           8.3         248.0
# 2022-01-01 01:15           8.3         248.0
# 2022-01-01 01:30           8.3         248.0
# 2022-01-01 01:45           8.3         248.0
# 2022-01-01 02:00           8.3         248.0

# %%
# Rename gage and flow rate colums to something humane and check the dataframe
df = df.rename(columns={"194446_00065": "Gage", "194445_00060": "Flow"  })
df.head()
# Out:
#                   Gage   Flow
# datetime
# 2022-01-01 01:00   8.3  248.0
# 2022-01-01 01:15   8.3  248.0
# 2022-01-01 01:30   8.3  248.0
# 2022-01-01 01:45   8.3  248.0
# 2022-01-01 02:00   8.3  248.0

# %%
#check the number of training rows
print('number of rows = ', df.shape[0])
# Out:
# number of rows =  98357

# %%
df = df.reset_index()

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df = df.set_index('datetime')

# %%
# Convert series to hours
df = df.resample('60Min').agg({'Gage': 'last', 'Flow': 'last'})#

# %%
# transform a time series dataset into a supervised learning dataset
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols = list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
    
    #put it all together
    agg = concat(cols, axis=1)
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg.values

# %%
# walk-forward validation for univariate data
def walk_forward_validation(data, n_test):
    predictions = list()

    # split dataset
    train, test = train_test_split(data, n_test)

    # seed history with training dataset
    history = [x for x in train]

    # step over each time-step in the test set
    for i in range(len(test)):
        # split test row into input and output columns
        testX, testy = test[i, :-1], test[i, -1]
        
        # fit model on history and make a prediction
        yhat = xgboost_forecast(history, testX)
        # store forecast in list of predictions
        predictions.append(yhat)
        # add actual observation to history for the next loop
        history.append(test[i])
        # summarize progress
        print('>expected=%.1f, predicted=%.1f' % (testy, yhat))

    # estimate prediction error
    #error = mean_absolute_error(test[:, -1], predictions)
    error = mean_squared_error(test[:, -1], predictions)
    return error, test[:, 1], predictions

# %%
# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
    return data[:-n_test, :], data[-n_test:, :]

# %%
def xgboost_forecast(train, testX):
    # transform list into array
    train = asarray(train)
    # split into input and output columns
    trainX, trainy = train[:, :-1], train[:, -1]

    # fit model
    model = XGBRegressor(objective='reg:squarederror', n_estimators=1000)
    model.fit(trainX, trainy)

    # make a one-step prediction
    
    yhat = model.predict([testX])
    return yhat[0]

# %%
df.head()
# Out:
#                      Gage   Flow
# datetime
# 2022-01-01 01:00:00  8.30  248.0
# 2022-01-01 02:00:00  8.30  248.0
# 2022-01-01 03:00:00  8.29  245.0
# 2022-01-01 04:00:00  8.29  245.0
# 2022-01-01 05:00:00  8.29  245.0

# %%
df = df.drop(['Flow'], axis=1)

# %%
df
# Out:
#                      Gage
# datetime
# 2022-01-01 01:00:00  8.30
# 2022-01-01 02:00:00  8.30
# 2022-01-01 03:00:00  8.29
# 2022-01-01 04:00:00  8.29
# 2022-01-01 05:00:00  8.29
# ...                   ...
# 2024-10-21 08:00:00  7.86
# 2024-10-21 09:00:00  7.86
# 2024-10-21 10:00:00  7.86
# 2024-10-21 11:00:00  7.86
# 2024-10-21 12:00:00  7.85
#
# [24588 rows x 1 columns]

# %%
# transform the time series data into supervised learning
data = series_to_supervised(df, n_in=1)

# %%
print (data)
# Out:
# [[8.3  8.3 ]
#  [8.3  8.29]
#  [8.29 8.29]
#  ...
#  [7.86 7.86]
#  [7.86 7.86]
#  [7.86 7.85]]

# %%
# evaluate
mse, y, yhat = walk_forward_validation(data, 24)
# Out:
# >expected=7.8, predicted=7.8
# >expected=7.8, predicted=7.8
# >expected=7.9, predicted=7.8
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.9, predicted=7.9
# >expected=7.8, predicted=7.9

# %%
# RMSE Computation 
rmse = np.sqrt(mse) 
print("RMSE : % f" %(rmse))
# Out:
# RMSE :  0.005217

# %%
# plot expected vs predicted
pyplot.plot(y, label='Expected')
pyplot.plot(yhat, label='Predicted')
pyplot.legend()
pyplot.show()
